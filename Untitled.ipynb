# %%
import os
from dotenv import load_dotenv, find_dotenv
#busca y carga el archivo .env
_ = load_dotenv(find_dotenv())

#cargamos chatgroq
from langchain_groq import ChatGroq

#instanciamos los modelos de llm
#TODO: Cambiar por una funcion
llamaChatModel = ChatGroq(
    model="llama3-70b-8192"
)

mistralChatModel = ChatGroq(
    model="mixtral-8x7b-32768"
)

#creamos un prompt
messages = [
    ("system", "You are an historian expert in the Kennedy family."),
    ("human", "How many members of the family died tragically?"),
]

llamaResponse = llamaChatModel.invoke(messages)

print(llamaResponse.content)
# Out:
# --------------------------------------------------------------------
# ModuleNotFoundError                Traceback (most recent call last)
# Cell In[7], line 2
#       1 import os
# ----> 2 from dotenv import load_dotenv, find_dotenv
#       3 #busca y carga el archivo .env
#       4 _ = load_dotenv(find_dotenv())
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
# !conda activate py_3_11_4

# %%
# !pip install dotenv
# Out:
# Collecting dotenv
#   Using cached dotenv-0.0.5.tar.gz (2.4 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [85 lines of output]
#   C:\Users\oscar\anaconda3\envs\py_3_11_4\Lib\site-packages\setuptools\__init__.py:94: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#   !!
#
#           ********************************************************************************
#           Requirements should be satisfied by a PEP 517 installer.
#           If you are using pip, you can try `pip install --use-pep517`.
#           ********************************************************************************
#
#   !!
#     dist.fetch_build_eggs(dist.setup_requires)
#     error: subprocess-exited-with-error
#
#     python setup.py egg_info did not run successfully.
#     exit code: 1
#
#     [17 lines of output]
#     Traceback (most recent call last):
#       File "<string>", line 2, in <module>
#       File "<pip-setuptools-caller>", line 14, in <module>
#       File "C:\Users\oscar\AppData\Local\Temp\pip-wheel-xrcs1xo_\distribute_8a185ada880d43978609c363c62f8849\setuptools\__init__.py", line 2, in <module>
#         from setuptools.extension import Extension, Library
#       File "C:\Users\oscar\AppData\Local\Temp\pip-wheel-xrcs1xo_\distribute_8a185ada880d43978609c363c62f8849\setuptools\extension.py", line 5, in <module>
#         from setuptools.dist import _get_unpatched
#       File "C:\Users\oscar\AppData\Local\Temp\pip-wheel-xrcs1xo_\distribute_8a185ada880d43978609c363c62f8849\setuptools\dist.py", line 7, in <module>
#         from setuptools.command.install import install
#       File "C:\Users\oscar\AppData\Local\Temp\pip-wheel-xrcs1xo_\distribute_8a185ada880d43978609c363c62f8849\setuptools\command\__init__.py", line 8, in <module>
#         from setuptools.command import install_scripts
#       File "C:\Users\oscar\AppData\Local\Temp\pip-wheel-xrcs1xo_\distribute_8a185ada880d43978609c363c62f8849\setuptools\command\install_scripts.py", line 3, in <module>
#         from pkg_resources import Distribution, PathMetadata, ensure_directory
#       File "C:\Users\oscar\AppData\Local\Temp\pip-wheel-xrcs1xo_\distribute_8a185ada880d43978609c363c62f8849\pkg_resources.py", line 1518, in <module>
#         register_loader_type(importlib_bootstrap.SourceFileLoader, DefaultProvider)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     AttributeError: module 'importlib._bootstrap' has no attribute 'SourceFileLoader'
#     [end of output]
#
#     note: This error originates from a subprocess, and is likely not a problem with pip.
#   error: metadata-generation-failed
#
#   Encountered error while generating package metadata.
#
#   See above for output.
#
#   note: This is an issue with the package mentioned above, not pip.
#   hint: See above for details.
#   Traceback (most recent call last):
#     File "C:\Users\oscar\anaconda3\envs\py_3_11_4\Lib\site-packages\setuptools\installer.py", line 102, in _fetch_build_egg_no_warn
#       subprocess.check_call(cmd)
#     File "C:\Users\oscar\anaconda3\envs\py_3_11_4\Lib\subprocess.py", line 413, in check_call
#       raise CalledProcessError(retcode, cmd)
#   subprocess.CalledProcessError: Command '['C:\\Users\\oscar\\anaconda3\\envs\\py_3_11_4\\python.exe', '-m', 'pip', '--disable-pip-version-check', 'wheel', '--no-deps', '-w', 'C:\\Users\\oscar\\AppData\\Local\\Temp\\tmpahfc7iqy', '--quiet', 'distribute']' returned non-zero exit status 1.
#
#   The above exception was the direct cause of the following exception:
#
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\oscar\AppData\Local\Temp\pip-install-uyl2a50n\dotenv_b374fa37cf084d1d9084840ea56a93aa\setup.py", line 13, in <module>
#       setup(name='dotenv',
#     File "C:\Users\oscar\anaconda3\envs\py_3_11_4\Lib\site-packages\setuptools\__init__.py", line 116, in setup
#       _install_setup_requires(attrs)
#     File "C:\Users\oscar\anaconda3\envs\py_3_11_4\Lib\site-packages\setuptools\__init__.py", line 89, in _install_setup_requires
#       _fetch_build_eggs(dist)
#     File "C:\Users\oscar\anaconda3\envs\py_3_11_4\Lib\site-packages\setuptools\__init__.py", line 94, in _fetch_build_eggs
#       dist.fetch_build_eggs(dist.setup_requires)
#     File "C:\Users\oscar\anaconda3\envs\py_3_11_4\Lib\site-packages\setuptools\dist.py", line 617, in fetch_build_eggs
#       return _fetch_build_eggs(self, requires)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\oscar\anaconda3\envs\py_3_11_4\Lib\site-packages\setuptools\installer.py", line 39, in _fetch_build_eggs
#       resolved_dists = pkg_resources.working_set.resolve(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\oscar\anaconda3\envs\py_3_11_4\Lib\site-packages\pkg_resources\__init__.py", line 897, in resolve
#       dist = self._resolve_dist(
#              ^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\oscar\anaconda3\envs\py_3_11_4\Lib\site-packages\pkg_resources\__init__.py", line 933, in _resolve_dist
#       dist = best[req.key] = env.best_match(
#                              ^^^^^^^^^^^^^^^
#     File "C:\Users\oscar\anaconda3\envs\py_3_11_4\Lib\site-packages\pkg_resources\__init__.py", line 1271, in best_match
#       return self.obtain(req, installer)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\oscar\anaconda3\envs\py_3_11_4\Lib\site-packages\pkg_resources\__init__.py", line 1307, in obtain
#       return installer(requirement) if installer else None
#              ^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\oscar\anaconda3\envs\py_3_11_4\Lib\site-packages\setuptools\installer.py", line 104, in _fetch_build_egg_no_warn
#       raise DistutilsError(str(e)) from e
#   distutils.errors.DistutilsError: Command '['C:\\Users\\oscar\\anaconda3\\envs\\py_3_11_4\\python.exe', '-m', 'pip', '--disable-pip-version-check', 'wheel', '--no-deps', '-w', 'C:\\Users\\oscar\\AppData\\Local\\Temp\\tmpahfc7iqy', '--quiet', 'distribute']' returned non-zero exit status 1.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
